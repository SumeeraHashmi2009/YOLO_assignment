# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# installing YOLO

# %%
# !unzip val2017.zip
# !unzip annotations_trainval2017.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: val2017/000000320425.jpg
#  extracting: val2017/000000481404.jpg
#  extracting: val2017/000000314294.jpg
#  extracting: val2017/000000335328.jpg
#  extracting: val2017/000000513688.jpg
#  extracting: val2017/000000158548.jpg
#  extracting: val2017/000000132116.jpg
#  extracting: val2017/000000415238.jpg
#  extracting: val2017/000000321333.jpg
#  extracting: val2017/000000081738.jpg
#  extracting: val2017/000000577584.jpg
#  extracting: val2017/000000346905.jpg
#  extracting: val2017/000000433980.jpg
#  extracting: val2017/000000228144.jpg
#  extracting: val2017/000000041872.jpg
#  extracting: val2017/000000117492.jpg
#  extracting: val2017/000000368900.jpg
#  extracting: val2017/000000376900.jpg
#  extracting: val2017/000000352491.jpg
#  extracting: val2017/000000330790.jpg
#  extracting: val2017/000000384850.jpg
#  extracting: val2017/000000032735.jpg
#  extracting: val2017/000000197004.jpg
# ...

# %% [markdown]
# Unzip downloaded files of dataset

# %%
from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir="annotations",
    save_dir="coco_yolo"
)

# %%
Run script

# %%
import os
os.makedirs("coco_ann", exist_ok=True)

# %% [markdown]
# SETUP for YOLO

# %%
# !cp annotations/instances_val2017.json coco_ann/

# %% [markdown]
# SEtUP for yolo

# %%
from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir="coco_ann",
    save_dir="coco_yolo"
)
# Out:
# Annotations /content/coco_ann/instances_val2017.json: 100% ━━━━━━━━━━━━ 4952/4952 2.2Kit/s 2.3s
# COCO data converted successfully.
# Results saved to /content/coco_yolo2

# %% [markdown]
# Converting annotations

# %%
# !ls coco_yolo
# Out:
# images	labels

# %%
# !mkdir -p coco_yolo/images/val
# !mv val2017/* coco_yolo/images/val/

# %%
move images for yolo folder

# %%
# !ls coco_yolo/labels
# Out:
# captions_train2017

# %%
# !mkdir -p coco_yolo/images/val
# !mv /content/val2017/* coco_yolo/images/val/

# %%
# !pwd
# Out:
# /content

# %%
# !mkdir -p /content/coco_yolo/images/val
# !mv /content/val2017/*.jpg /content/coco_yolo/images/val/

# %%
# !rm -rf /content/val2017

# %%
import os
os.makedirs("coco_ann", exist_ok=True)

# %%
# !cp annotations/instances_val2017.json coco_ann/

# %%
from ultralytics.data.converter import convert_coco

convert_coco(
    labels_dir="coco_ann",
    save_dir="coco_yolo"
)
# Out:
# Annotations /content/coco_ann/instances_val2017.json: 100% ━━━━━━━━━━━━ 4952/4952 2.3Kit/s 2.2s
# COCO data converted successfully.
# Results saved to /content/coco_yolo

# %%
# !ls coco_yolo/labels
# Out:
# val2017

# %%
# !mkdir -p /content/coco_yolo/images/val
# !mv /content/val2017/* /content/coco_yolo/images/val/

# %% [markdown]
# SET UP For YOLO

# %%
# !unzip /content/val2017.zip

# %%
# !mv /content/coco_yolo/labels/val2017 /content/coco_yolo/labels/val

# %%
# %%writefile coco.yaml
# path: /content/coco_yolo
#
# train: images/val
# val: images/val
#
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light
# Out:
# Writing coco.yaml

# %% [markdown]
# ONLY 10 CLASSES AS PER THE ASSIGNMENT REQUIREMENT

# %%
# !cat coco.yaml
# Out:
# path: /content/coco_yolo
#
# train: images/val
# val: images/val
#
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light

# %%
# !yolo detect train data=coco.yaml model=yolov8n.pt epochs=30 imgsz=640

# %% [markdown]
# YOLO TRAINING

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=/content/coco_yolo/images/val
# Out:
# Streaming output truncated to the last 5000 lines.
# image 4/5000 /content/coco_yolo/images/val/000000000724.jpg: 640x480 1 truck, 76.4ms
# image 5/5000 /content/coco_yolo/images/val/000000000776.jpg: 640x448 (no detections), 68.5ms
# image 6/5000 /content/coco_yolo/images/val/000000000785.jpg: 448x640 1 person, 13.8ms
# image 7/5000 /content/coco_yolo/images/val/000000000802.jpg: 640x448 (no detections), 13.5ms
# image 8/5000 /content/coco_yolo/images/val/000000000872.jpg: 640x640 3 persons, 14.7ms
# image 9/5000 /content/coco_yolo/images/val/000000000885.jpg: 448x640 2 persons, 1 bicycle, 13.9ms
# image 10/5000 /content/coco_yolo/images/val/000000001000.jpg: 480x640 14 persons, 68.7ms
# image 11/5000 /content/coco_yolo/images/val/000000001268.jpg: 448x640 5 persons, 2 boats, 13.8ms
# image 12/5000 /content/coco_yolo/images/val/000000001296.jpg: 640x448 1 person, 13.3ms
# ...

# %% [markdown]
# YOLO PREDICTIONS

# %%
# !zip -r predictions.zip runs/detect/predict
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: runs/detect/predict/000000376322.jpg (deflated 0%)
#   adding: runs/detect/predict/000000217219.jpg (deflated 0%)
#   adding: runs/detect/predict/000000102707.jpg (deflated 3%)
#   adding: runs/detect/predict/000000419096.jpg (deflated 2%)
#   adding: runs/detect/predict/000000327592.jpg (deflated 1%)
#   adding: runs/detect/predict/000000579902.jpg (deflated 0%)
#   adding: runs/detect/predict/000000420281.jpg (deflated 0%)
#   adding: runs/detect/predict/000000461275.jpg (deflated 0%)
#   adding: runs/detect/predict/000000078032.jpg (deflated 0%)
#   adding: runs/detect/predict/000000179765.jpg (deflated 2%)
#   adding: runs/detect/predict/000000419408.jpg (deflated 0%)
#   adding: runs/detect/predict/000000401244.jpg (deflated 2%)
#   adding: runs/detect/predict/000000062355.jpg (deflated 0%)
#   adding: runs/detect/predict/000000215259.jpg (deflated 1%)
#   adding: runs/detect/predict/000000578967.jpg (deflated 0%)
# ...

# %%
from google.colab import files
files.download("predictions.zip")

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/yolo_assignment/

# %%
# !yolo detect train data=coco.yaml model=/content/runs/detect/train/weights/best.pt imgsz=416
# Out:
# Streaming output truncated to the last 5000 lines.
# train: /content/coco_yolo/images/val/000000515445.jpg: ignoring corrupt image/label: Label class 37 exceeds dataset class count 10. Possible class labels are 0-9
# train: /content/coco_yolo/images/val/000000515577.jpg: ignoring corrupt image/label: Label class 30 exceeds dataset class count 10. Possible class labels are 0-9
# train: /content/coco_yolo/images/val/000000515579.jpg: ignoring corrupt image/label: Label class 58 exceeds dataset class count 10. Possible class labels are 0-9
# train: /content/coco_yolo/images/val/000000515828.jpg: ignoring corrupt image/label: Label class 56 exceeds dataset class count 10. Possible class labels are 0-9
# train: /content/coco_yolo/images/val/000000515982.jpg: ignoring corrupt image/label: Label class 35 exceeds dataset class count 10. Possible class labels are 0-9
# ...

# %%
# !cp /content/coco.yaml /content/drive/MyDrive/yolo_assignment/

# %%
# !ls /content/drive/MyDrive/yolo_assignment
# Out:
# coco.yaml  coco_yolo  predict  runs

# %%
# !cat /content/drive/MyDrive/yolo_assignment/coco.yaml
# Out:
# path: /content/coco_yolo
#
# train: images/val
# val: images/val
#
# names:
#   0: person
#   1: bicycle
#   2: car
#   3: motorcycle
#   4: airplane
#   5: bus
#   6: train
#   7: truck
#   8: boat
#   9: traffic light

# %%
# !ls /content/drive/MyDrive/yolo_assignment/coco_yolo/images/val | wc -l
# Out:
# 5000
